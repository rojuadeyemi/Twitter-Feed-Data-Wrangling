# %% [markdown]
# # Project: Data Wrangling and Analysis
#
#  ---
# # <center> Insights from Wrangled Twitter Datasets </center>
# # <center>A.T. Aderoju </center>
#
# ### Overview
#
# With the cleansed dataset created from gathering twitter data pertaining to the popular  [WeRateDogs](https://en.wikipedia.org/wiki/WeRateDogs) rating provider on Twitter, I analyzed and produced the following insights:
# 1) Most occuring Dog stage according to the Neural Network's image prediction.
# 2) The most Popular Breed on `@WeRateDogs`
# 3) Engagement Frequency of the `WeRateDog` account
# 4) Relationship Between Posts Retweeting & Favourism
# 5) Influence of Post Retweeting on Number of Times a Post is Liked
#  ---

# %% [markdown]
# #### Most occuring Dog stage according to the Neural Network's image prediction
#
# **The analysis of the WeRateDogs Twittter account shows that dogs in pupper stage are the most occuring, followed by those in doggo stage**
#
# <img src="./Pictures/Distribution of Dogs.png" alt="Ade" style="width:700px;">
#
# <table>
#     <tr>
#         <td style="text-align: center;">
#             <div>Pupper</div>
#             <div>
#             <img src="./Pictures/Pupper.jpg" alt="Image 1" style="width: 200px;"/>
#             </div>
#         </td>
#         <td style="text-align: center;">
#             <div>Doggo</div>
#             <div>
#             <img src="./Pictures/Doggo.jpg" alt="Image 1" style="width: 200px;"/>
#             </div>
#         </td>
#     </tr>
#     <tr>
#         <td style="text-align: center;">
#             <div>Puppo</div>
#             <div>
#             <img src="./Pictures/Puppo.jpg" alt="Image 1" style="width: 200px;"/>
#             </div>
#         </td>
#         <td style="text-align: center;">
#             <div>Floofer</div>
#             <div>
#             <img src="./Pictures/Floofer.jpg" alt="Image 1" style="width: 300px;"/>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# #### The most Popular Breed on `@WeRateDogs`
#
# **Whereas Golden Retriever lead the list of breed with most liked tweets and retweet, Saluki has the highest likes per tweet, while Bedlington Terrier experienced the highest retweet per post . Hence, in terms of total likes and retweet, Golden Retriver is the most popular breed on Twitter**
#
# <img src="./Pictures/Most Tweeted.png" alt="Dog" style="width:700px;">
#
#
# <div>
# <img src="./Pictures/top10byfav.png" alt="Image 1"/>
# </div>
# <div>
# <img src="./Pictures/top10byretweet.png" alt="Image 1"/>
# </div>
#
# **Golden Retrievers are the most liked and retweeted @WeRateDogs. See below for an image of a set of golden retrievers.**
#
# <img src="./Pictures/Golden Retriever.png" alt="Image 1"/>
#
# **In terms of per post, we have Saluki breed having the highest likes per post, with Bedlington Terrier having the highest retweeted count on, average**
# <div>
# <img src="./Pictures/top10byfav_average.png" alt="Image 1"/>
# </div>
# <div>
# <img src="./Pictures/top10byretweet_average.png" alt="Image 2"/>
# </div>
# <table>
#     <tr>
#         <td style="text-align: center;">
#             <div>Saluki</div>
#             <div>
#             <img src="./Pictures/Saluki.png" alt="Image 1" style="width: 400px;"/>
#             </div>
#         </td>
#         <td style="text-align: center;">
#             <div>Bedlington Terrier</div>
#             <div>
#             <img src="./Pictures/Bedlington Terrier.png" alt="Image 2" style="width: 400px;"/>
#             </div>
#         </td>
#     </tr>
# </table>
#
# **We also looked at the dogs with highest likes and retweet @WeRateDogs, and below are their images**
#
# <table>
#     <tr>
#         <td style="text-align: center;">
#             <div>Highest Likes - Lakeland Terrier</div>
#             <div>
#             <img src="./Pictures/highest_likes_dog.png" alt="Image 1" style="width: 400px;height:500px;"/>
#             </div>
#         </td>
#         <td style="text-align: center;">
#             <div>Highest Repost - Labrador Retriever </div>
#             <div>
#             <img src="./Pictures/highest_retweet_dog.png" alt="Image 2" style="width: 400px;"/>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# #### Engagement Frequency of the `WeRateDog` account
#
# **Accross the year, Monday seems the most busy day of the account, and people Like to interract with in the early midnight of the day, lowest during the day and become high again between 4PM to 5PM. This is undesrtandable as most people become less active on the internet during work hours**
#
# <img src="./Pictures/daily.png" alt="Image 2"/>
# <img src="./Pictures/hourly.png" alt="Image 2"/>

# %% [markdown]
# #### Relationship Between Posts Retweeting & Favourism
#
# **The Pearson's r of rating and favorite count is around 0.5, which means there is a moderately positive correlation between the variables. This implies that ratings somewhat reflect people's preferences for dogs.**
#
# <img src="./Pictures/rating&Favourite.png" alt="Image 1"/>
# <img src="./Pictures/fav_rating_corr.png" alt="Image 2"/>
# <center>Top & Worst Rated Dogs</center>
# <table>
#     <tr>
#         <td style="text-align: center;">
#             <div>Top Rated</div>
#             <div>
#             <img src="./Pictures/Top rated.jpg" alt="Image 1" style="width: 400px;"/>
#             </div>
#         </td>
#         <td style="text-align: center;">
#             <div>Worst Rated</div>
#             <div>
#             <img src="./Pictures/Worst Rated.jpg" alt="Image 2" style="width: 400px;"/>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# #### Influence of Post Retweeting on Number of Times a Post is Liked
# **There is a strong positive linear relation between post retweet and number of time a post receives likes. This implies that people who like a post are highly likely to retweet and vice versa.**
#
# <img src="./Pictures/Retweet&Favorite.png" alt="Image 1">
# <img src="./Pictures/ret_fav_corr.png" alt="Image 2">
#
# **From the begining till 2016-04, the intensity of both favorite and retweet counts is similar, although favorite counts are higher than retweet counts. This trend is even more conspicuous with the progression of time, with favorite counts steadily rising above retweet counts from around 2016-09. Interestingly, the bulk of retweet counts remains below 10k.**
#
# <img src="./Pictures/Tweet_Type.png" alt="Image 1">
